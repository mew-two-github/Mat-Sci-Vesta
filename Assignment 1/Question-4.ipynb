# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sin, radians, sqrt
from sklearn.preprocessing import StandardScaler as SS

# %%
X0_data = pd.read_excel('Cs2AgInCl6.xlsx',sheet_name = 'part b)')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
X0_data.head()
# Out:
#         2θ    I
# 500  20.00  566
# 501  20.02  528
# 502  20.04  570
# 503  20.06  523
# 504  20.08  556

# %%
X0_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2001 entries, 500 to 2500
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2θ      2001 non-null   float64
#  1   I       2001 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 46.9 KB

# %%
#from sklearn.preprocessing import StandardScaler as SS
#scaler = SS()

# %%
#X0_data['I_normalised'] = scaler.fit_transform(np.asarray(X0_data['I']).reshape(-1, 1))
X0_data['I_normalised'] = X0_data['I']/max(X0_data['I'])
X0_data.to_excel('normalised_x0.xlsx')

# %%
plt.figure(figsize=(10,10))
plt.xlabel('2θ'); plt.ylabel('Intensity')
plt.plot(X0_data['2θ'],X0_data['I'])

# %%
plt.figure(figsize=(10,10))
plt.xlabel('2θ'); plt.ylabel('Normalised Intensity'); plt.title('Experimental XRD')
plt.plot(X0_data['2θ'],X0_data['I_normalised'])

# %%
X0_vesta = pd.read_excel('Cs2AgInCl6.xlsx',sheet_name = 'xrd_data')
X0_vesta = X0_vesta.loc[(X0_vesta['2θ']<=60) & (X0_vesta['2θ']>=20)]
#X0_vesta['I_normalised'] = scaler.fit_transform(np.asarray(X0_vesta['I']).reshape(-1, 1))
X0_vesta['I_normalised'] = X0_vesta['I']/max(X0_vesta['I'])
plt.figure(figsize=(10,10))
plt.xlabel('2θ'); plt.ylabel('Normalised Intensity'); plt.title('XRD from Vesta')
plt.plot(X0_vesta['2θ'],X0_vesta['I_normalised'])

# %%
plt.figure(figsize=(10,10))
plt.xlabel('2θ'); plt.ylabel('Normalised Intensity'); plt.title('XRD from Vesta')
plt.plot(X0_data['2θ'],X0_data['I_normalised'],X0_vesta['2θ'],X0_vesta['I_normalised'])
plt.legend(["Experimental","Vesta"],loc ="upper right")

# %% [markdown]
# <h3>Lattice Parameters</h3>

# %%
wvlength = 1.5406
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)

# %%
X0_data[X0_data.I == X0_data.I.max()]
# Out:
#         2θ      I  I_normalised
# 667  23.34  58725     17.835445

# %%
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# Distance between the planes: 3.7110329454352606 Angstrom
# Lattice Parameter: 10.49638624369584 Angstrom

# %% [markdown]
# <b>Conclusion:</b>
# <ol>
#     <li>As seen from the peaks, and the data used in Excel in part a), the experimental data and the Vesta generated data  are <b>nearly identical</b> but not the same. </li>
#     <li>Lattice Parameter from Vesta: <b>a = 10.48059 Angstrom</b> </li>
#     <li>Lattice Parameter from Experimental data: <b>a = 10.49638 Angstrom</b> </li>
# </ol>

# %% [markdown]
# <h1>Part C</h1>

# %%
lattice_params = []
wvlength = 1.5406
X0_data = pd.read_excel('XRD.xlsx',sheet_name = 'x=0')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)
lattice_params.append(a)
print(theta)
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# 667    23.34
# Name: 2θ, dtype: float64
# Distance between the planes: 3.808190445568903 Angstrom
# Lattice Parameter: 10.771189152446365 Angstrom

# %%
wvlength = 1.5406
X0_data = pd.read_excel('XRD.xlsx',sheet_name = 'x=0.2')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)
lattice_params.append(a)
print(theta)
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# 671    23.42
# Name: 2θ, dtype: float64
# Distance between the planes: 3.795362809771921 Angstrom
# Lattice Parameter: 10.734907119411817 Angstrom

# %%
wvlength = 1.5406
X0_data = pd.read_excel('XRD.xlsx',sheet_name = 'x=0.4')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)
lattice_params.append(a)
print(theta)
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# 680    23.6
# Name: 2θ, dtype: float64
# Distance between the planes: 3.7668208899991256 Angstrom
# Lattice Parameter: 10.654178379334112 Angstrom

# %%
wvlength = 1.5406
X0_data = pd.read_excel('XRD.xlsx',sheet_name = 'x=0.6')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)
lattice_params.append(a)
print(theta)
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# 685    23.7
# Name: 2θ, dtype: float64
# Distance between the planes: 3.7511529668016514 Angstrom
# Lattice Parameter: 10.609862800373936 Angstrom

# %%
wvlength = 1.5406
X0_data = pd.read_excel('XRD.xlsx',sheet_name = 'x=0.8')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)
lattice_params.append(a)
print(theta)
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# 692    23.84
# Name: 2θ, dtype: float64
# Distance between the planes: 3.729440324301225 Angstrom
# Lattice Parameter: 10.548450173375812 Angstrom

# %%
wvlength = 1.5406
X0_data = pd.read_excel('XRD.xlsx',sheet_name = 'x=1')
X0_data = X0_data.loc[(X0_data['2θ']<=60) & (X0_data['2θ']>=20)]
theta = X0_data[X0_data.I == X0_data.I.max()]['2θ']
d = wvlength/(2*sin(radians(theta/2)))
a = d*sqrt(8)
lattice_params.append(a)
print(theta)
print('Distance between the planes: {} Angstrom \nLattice Parameter: {} Angstrom'.format(d,a))
# Out:
# 698    23.96
# Name: 2θ, dtype: float64
# Distance between the planes: 3.7110329454352606 Angstrom
# Lattice Parameter: 10.49638624369584 Angstrom

# %%
x = [0,0.2,0.4,0.6,0.8,1]
plt.figure(figsize=(7.5,7.5))
plt.title('Substitution of $Bi^{3+}$ by $In^{3+}$')
plt.xlabel('Composition of $In^{3+}$'); plt.ylabel('Lattice parameter a (in $\AA$)')
plt.plot(x,lattice_params)
